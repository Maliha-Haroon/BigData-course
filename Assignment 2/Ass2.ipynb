# %% [markdown]
# # **Celsius to Fahrenheit Conversion**

# %%
celsius = float(input("Enter temperature in Centigrade: "))

fahrenheit = (celsius * 9/5) + 32

print("Temperature in Fahrenheit:", fahrenheit)
# Out:
# Enter temperature in Centigrade:  28
# Temperature in Fahrenheit: 82.4

# %% [markdown]
# # **Area of Triangle Using Sides (Heron's Formula)**

# %%
import math

a = float(input("Enter first side: "))
b = float(input("Enter second side: "))
c = float(input("Enter third side: "))

s = (a + b + c) / 2  # Semi-perimeter

area = math.sqrt(s * (s - a) * (s - b) * (s - c))

print("Area of the triangle:", area)
# Out:
# Enter first side:  13
# Enter second side:  14
# Enter third side:  15
# Area of the triangle: 84.0

# %% [markdown]
# # **Average of a List of Numbers**

# %%
n = int(input("Enter how many numbers you want to input: "))

numbers = []

for i in range(n):
    num = float(input("Enter number: "))
    numbers.append(num)

average = sum(numbers) / n

print("List:", numbers)
print("Average:", average)
# Out:
# Enter how many numbers you want to input:  2
# Enter number:  3
# Enter number:  3
# List: [3.0, 3.0]
# Average: 3.0

# %% [markdown]
# # **Integers from 100–200 whose Digit Sum is Even**

# %%
for num in range(100, 201):
    digit_sum = sum(int(digit) for digit in str(num))
    
    if digit_sum % 2 == 0:
        print(num)
# Out:
# 101
# 103
# 105
# 107
# 109
# 110
# 112
# 114
# 116
# 118
# 121
# 123
# 125
# 127
# 129
# 130
# 132
# 134
# 136
# 138
# 141
# 143
# 145
# 147
# 149
# 150
# 152
# 154
# 156
# 158
# 161
# 163
# 165
# 167
# 169
# 170
# 172
# 174
# 176
# 178
# 181
# 183
# 185
# 187
# 189
# 190
# 192
# 194
# 196
# 198
# 200

# %% [markdown]
# # **Linear Search Without Using 'in'**

# %%
n = int(input("Enter number of elements: "))

arr = []

for i in range(n):
    value = int(input("Enter element: "))
    arr.append(value)

search = int(input("Enter element to search: "))

found = False

for i in range(n):
    if arr[i] == search:
        print("Element found at index:", i)
        found = True
        break

if not found:
    print("Element not found")
# Out:
# Enter number of elements:  2
# Enter element:  1
# Enter element:  4
# Enter element to search:  2
# Element not found

# %% [markdown]
# # **Check Prime Number**

# %%
num = int(input("Enter a number: "))

if num <= 1:
    print("Not a Prime Number")
else:
    prime = True
    for i in range(2, int(num**0.5) + 1):
        if num % i == 0:
            prime = False
            break

    if prime:
        print("Prime Number")
    else:
        print("Not a Prime Number")
# Out:
# Enter a number:  4
# Not a Prime Number

# %% [markdown]
# # **Leap Year Program**

# %%
year = int(input("Enter a year: "))

if (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0):
    print("Leap Year")
else:
    print("Not a Leap Year")
# Out:
# Enter a year:  2013
# Not a Leap Year
